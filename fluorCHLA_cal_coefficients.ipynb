# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import plotly.express as px
import numpy as np
from db_api import get_cal, get_metadata_all

# %%
BASE_URL = "https://db.whoifloatgroup.org"
#BASE_URL = "http://127.0.0.1:8000"

headers = {'Content-Type':'application/json'}

def get_wmo_assigned(PLATFORM_TYPE):
    response = requests.get(BASE_URL+"/api/wmo_assigned", headers=headers,
            params={"PLATFORM_TYPE":PLATFORM_TYPE})
    
    if response.status_code==200:
        return pd.DataFrame(json.loads(response.content))
    raise Exception('ERROR: ', response.status_code)

PLATFORMTYPE = "&PLATFORM_TYPE=NAVIS_EBR"

def get_cal2(floatnum):
    floatnum = "FLOAT_SERIAL_NO=" + str(floatnum) + PLATFORMTYPE
    response = requests.get(BASE_URL+"/api/cal?"+floatnum)

    if response.status_code==200:
        return pd.DataFrame(json.loads(response.content))
    raise Exception('ERROR: ', response.status_code)

# %%
sn = get_metadata_all("FLOAT_SERIAL_NO")
WMO = get_metadata_all("PLATFORM_NUMBER")

df = pd.concat([sn, WMO], axis=1)
df
# Out:
#    FLOAT_SERIAL_NO PLATFORM_NUMBER
# 0             1528               8
# 1             1343         4903456
# 2             1529              29
# 3             1530            None
# 4             1477         4903533
# 5             1539            None
# 6             1475         4903489
# 7             1476         4903532
# 8             1359         4903462
# 9             1361         4903487
# 10            1478            None
# 11            1479            None
# 12            1474         4903488
# 13            1360         4903463
# 14            1480            None
# 15            1481            None
# 16            1486         1902458
# 17            1487         1902459
# 18            1344         4903457
# 19            1482         1902453
# 20            1483               3
# 21            1484         1902454
# 22            1485         1902455
# 23            1488         1902456
# 24            1489               9
# 25            1490         1902457
# 26            1203         1902304
# 27            1358              58
# 28            1357         4903274
# 29            1356         4903486
# 30            1345         1902380
# 31            1346         4903365
# 32            1351         1902383
# 33            1201         1902303
# 34            1347         1902381
# 35            1348         1902382
# 36            1355         1902385
# 37            1354         4903485
# 38            1352         1902384
# 39            1200         4903273
# 40            1349         4903458
# 41            1350         4903459
# 42            1353         4903460

# %%
flts = get_wmo_assigned("NAVIS_EBR")
sn = flts.FLOAT_SERIAL_NO
sn
# Out:
# 0     1528
# 1     1343
# 2     1529
# 3     1477
# 4     1475
# 5     1476
# 6     1359
# 7     1361
# 8     1474
# 9     1360
# 10    1486
# 11    1487
# 12    1344
# 13    1482
# 14    1483
# 15    1484
# 16    1485
# 17    1488
# 18    1489
# 19    1490
# 20    1203
# 21    1358
# 22    1357
# 23    1356
# 24    1345
# 25    1346
# 26    1351
# 27    1201
# 28    1347
# 29    1348
# 30    1355
# 31    1354
# 32    1352
# 33    1200
# 34    1349
# 35    1350
# 36    1353
# Name: FLOAT_SERIAL_NO, dtype: object

# %%
meta = []
for sns in (sn):
    df = get_cal2(sns)
    meta.append(df)
meta

display(meta[0])
# Out:
#                                                                           CTD_CNDC  \
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                        SBE41CP_V5.3.5
# SENSOR_SERIAL_NO                                                             18947
# SENSOR_CALIB_DATE                                                       2023-03-12
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'G': -1.01677, 'H': 0.1431673, 'I': -0.000169...
#
#                                                                           CTD_PRES  \
# SENSOR_MAKER                                                                 DRUCK
# SENSOR_MODEL                                                        DRUCK_2900PSIA
# SENSOR_SERIAL_NO                                                          12263199
# SENSOR_CALIB_DATE                                                       2023-03-16
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'PA0': 0.2982393, 'PA1': 0.0003909299, 'PA2':...
#
#                                                                           CTD_TEMP  \
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                        SBE41CP_V5.3.5
# SENSOR_SERIAL_NO                                                             18947
# SENSOR_CALIB_DATE                                                       2023-03-12
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'TA0': -0.0008992448, 'TA1': 0.0003029106, 'T...
#
#                                                                        OPTODE_DOXY  \
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                          SBE63_V3.2.2
# SENSOR_SERIAL_NO                                                              3419
# SENSOR_CALIB_DATE                                                       2023-03-08
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'E': 0.011, 'A0': 1.0513, 'A1': -0.0015, 'A2'...
#
#                                                          FLUOROMETER_CDOM  \
# SENSOR_MAKER                                                      WETLABS
# SENSOR_MODEL                                                 MCOMS_FLBBCD
# SENSOR_SERIAL_NO                                                      419
# SENSOR_CALIB_DATE                                                    None
# COMMENTS
# PREDEPLOYMENT_CALIB_EQUATION                                {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'DARK_CDOM': 50, 'SCALE_CDOM': 0.04084}
#
#                                                           FLUOROMETER_CHLA  \
# SENSOR_MAKER                                                       WETLABS
# SENSOR_MODEL                                                  MCOMS_FLBBCD
# SENSOR_SERIAL_NO                                                       419
# SENSOR_CALIB_DATE                                                     None
# COMMENTS
# PREDEPLOYMENT_CALIB_EQUATION                                 {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.002349}
#
#                                                         BACKSCATTERINGMETER_BBP700  \
# SENSOR_MAKER                                                               WETLABS
# SENSOR_MODEL                                                          MCOMS_FLBBCD
# SENSOR_SERIAL_NO                                                               419
# SENSOR_CALIB_DATE                                                             None
# COMMENTS
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'KHI': 1.097, 'BETASW700': 'calculated at 124...
#
#                                                          SPECTROPHOTOMETER_NITRATE  \
# SENSOR_MAKER                                                             SATLANTIC
# SENSOR_MODEL                                                               SUNA_V2
# SENSOR_SERIAL_NO                                                              2068
# SENSOR_CALIB_DATE                                                             None
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'NO3': [-0.00022323, 0.00585584, 0.00472827, ...
#
#                                                                      TRANSISTOR_PH
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                                SEAFET
# SENSOR_SERIAL_NO                                                         720-12256
# SENSOR_CALIB_DATE                                                       2023-03-14
# COMMENTS                           REF SN: 12246; added calibration date; added K0
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'F0': -1.332894357998, 'F1': 8.811211536684e-...

# %%
cal = []
for i, metas in enumerate(meta):
    cal.append(metas["FLUOROMETER_CHLA"].PREDEPLOYMENT_CALIB_COEFFICIENT)
cal
# Out:
# [{'DARK_CHLA': 49, 'SCALE_CHLA': 0.002349},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.003133},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.002204},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.002211},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001667},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001758},
#  {'DARK_CHLA': 51, 'SCALE_CHLA': 0.001847},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001842},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001729},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001705},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001925},
#  {'DARK_CHLA': 48, 'SCALE_CHLA': 0.00219},
#  {'DARK_CHLA': None, 'SCALE_CHLA': None},
#  {'DARK_CHLA': 51, 'SCALE_CHLA': 0.002159},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.002094},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.002159},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.002047},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001684},
#  {'DARK_CHLA': 51, 'SCALE_CHLA': 0.001868},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001681},
#  {'DARK_CHLA': 50.0, 'SCALE_CHLA': 0.001692},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001746},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001921},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001977},
#  {'DARK_CHLA': 50.0, 'SCALE_CHLA': 0.001747},
#  {'DARK_CHLA': 50.0, 'SCALE_CHLA': 0.001881},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001583},
#  {'DARK_CHLA': 50.0, 'SCALE_CHLA': 0.001874},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001577},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001606},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001574},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001952},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001443},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001634},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001771},
#  {'DARK_CHLA': 50, 'SCALE_CHLA': 0.001748},
#  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.001986}]

# %%
variables = ["DARK_CHLA","SCALE_CHLA"]
counter = 0

for variable in variables:
    coefficients = []
    serials = []
    counter2 = 0
    for num in cal: 
        if variable in num:
            coefficients.append(num[variable])
            serials.append(sn[counter2])
        counter2+=1
    
    coefficient_array = np.array(coefficients)
    coeff_array = np.delete(coefficient_array, np.where(coefficient_array == None))
    #print(coeff_array)
    print(variable)
    mean = coeff_array.mean()
    std = coeff_array.std()
    print("The mean is:", coeff_array.mean())
    print("The std is:", coeff_array.std())

    plt.figure(counter)
    plt.xlabel("FLOAT SERIAL NO")
    plt.ylabel("VALUE")
    plt.title(variable)
    plt.scatter(serials,coefficients)
    plt.axhline(y = mean, color='green')
    #plt.axhline(y = std, color= 'red')
    plt.xticks(rotation= 75)
    counter+=1
# Out:
# DARK_CHLA
# The mean is: 49.611111111111114
# The std is: 0.6781419786518724
# SCALE_CHLA
# The mean is: 0.0018878888888888893
# The std is: 0.000300563709069935
