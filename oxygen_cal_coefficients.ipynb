# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import plotly.express as px
import numpy as np
from db_api import get_cal, get_metadata_all

# %%
BASE_URL = "https://db.whoifloatgroup.org"
#BASE_URL = "http://127.0.0.1:8000"

headers = {'Content-Type':'application/json'}

def get_wmo_assigned(PLATFORM_TYPE):
    response = requests.get(BASE_URL+"/api/wmo_assigned", headers=headers,
            params={"PLATFORM_TYPE":PLATFORM_TYPE})
    
    if response.status_code==200:
        return pd.DataFrame(json.loads(response.content))
    raise Exception('ERROR: ', response.status_code)

PLATFORMTYPE = "&PLATFORM_TYPE=NAVIS_EBR"

def get_cal2(floatnum):
    floatnum = "FLOAT_SERIAL_NO=" + str(floatnum) + PLATFORMTYPE
    response = requests.get(BASE_URL+"/api/cal?"+floatnum)

    if response.status_code==200:
        return pd.DataFrame(json.loads(response.content))
    raise Exception('ERROR: ', response.status_code)

# %%
sn = get_metadata_all("FLOAT_SERIAL_NO")
WMO = get_metadata_all("PLATFORM_NUMBER")

df = pd.concat([sn, WMO], axis=1)
df
# Out:
#    FLOAT_SERIAL_NO PLATFORM_NUMBER
# 0             1528               8
# 1             1343         4903456
# 2             1529              29
# 3             1530            None
# 4             1477         4903533
# 5             1539            None
# 6             1475         4903489
# 7             1476         4903532
# 8             1359         4903462
# 9             1361         4903487
# 10            1478            None
# 11            1479            None
# 12            1474         4903488
# 13            1360         4903463
# 14            1480            None
# 15            1481            None
# 16            1486         1902458
# 17            1487         1902459
# 18            1344         4903457
# 19            1482         1902453
# 20            1483               3
# 21            1484         1902454
# 22            1485         1902455
# 23            1488         1902456
# 24            1489               9
# 25            1490         1902457
# 26            1203         1902304
# 27            1358              58
# 28            1357         4903274
# 29            1356         4903486
# 30            1345         1902380
# 31            1346         4903365
# 32            1351         1902383
# 33            1201         1902303
# 34            1347         1902381
# 35            1348         1902382
# 36            1355         1902385
# 37            1354         4903485
# 38            1352         1902384
# 39            1200         4903273
# 40            1349         4903458
# 41            1350         4903459
# 42            1353         4903460

# %%
flts = get_wmo_assigned("NAVIS_EBR")
sn = flts.FLOAT_SERIAL_NO
sn
# Out:
# 0     1528
# 1     1343
# 2     1529
# 3     1477
# 4     1475
# 5     1476
# 6     1359
# 7     1361
# 8     1474
# 9     1360
# 10    1486
# 11    1487
# 12    1344
# 13    1482
# 14    1483
# 15    1484
# 16    1485
# 17    1488
# 18    1489
# 19    1490
# 20    1203
# 21    1358
# 22    1357
# 23    1356
# 24    1345
# 25    1346
# 26    1351
# 27    1201
# 28    1347
# 29    1348
# 30    1355
# 31    1354
# 32    1352
# 33    1200
# 34    1349
# 35    1350
# 36    1353
# Name: FLOAT_SERIAL_NO, dtype: object

# %%
meta = []
for sns in (sn):
    df = get_cal2(sns)
    meta.append(df)
meta

display(meta[0])
# Out:
#                                                                           CTD_CNDC  \
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                        SBE41CP_V5.3.5
# SENSOR_SERIAL_NO                                                             18947
# SENSOR_CALIB_DATE                                                       2023-03-12
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'G': -1.01677, 'H': 0.1431673, 'I': -0.000169...
#
#                                                                           CTD_PRES  \
# SENSOR_MAKER                                                                 DRUCK
# SENSOR_MODEL                                                        DRUCK_2900PSIA
# SENSOR_SERIAL_NO                                                          12263199
# SENSOR_CALIB_DATE                                                       2023-03-16
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'PA0': 0.2982393, 'PA1': 0.0003909299, 'PA2':...
#
#                                                                           CTD_TEMP  \
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                        SBE41CP_V5.3.5
# SENSOR_SERIAL_NO                                                             18947
# SENSOR_CALIB_DATE                                                       2023-03-12
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'TA0': -0.0008992448, 'TA1': 0.0003029106, 'T...
#
#                                                                        OPTODE_DOXY  \
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                          SBE63_V3.2.2
# SENSOR_SERIAL_NO                                                              3419
# SENSOR_CALIB_DATE                                                       2023-03-08
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'E': 0.011, 'A0': 1.0513, 'A1': -0.0015, 'A2'...
#
#                                                          FLUOROMETER_CDOM  \
# SENSOR_MAKER                                                      WETLABS
# SENSOR_MODEL                                                 MCOMS_FLBBCD
# SENSOR_SERIAL_NO                                                      419
# SENSOR_CALIB_DATE                                                    None
# COMMENTS
# PREDEPLOYMENT_CALIB_EQUATION                                {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'DARK_CDOM': 50, 'SCALE_CDOM': 0.04084}
#
#                                                           FLUOROMETER_CHLA  \
# SENSOR_MAKER                                                       WETLABS
# SENSOR_MODEL                                                  MCOMS_FLBBCD
# SENSOR_SERIAL_NO                                                       419
# SENSOR_CALIB_DATE                                                     None
# COMMENTS
# PREDEPLOYMENT_CALIB_EQUATION                                 {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'DARK_CHLA': 49, 'SCALE_CHLA': 0.002349}
#
#                                                         BACKSCATTERINGMETER_BBP700  \
# SENSOR_MAKER                                                               WETLABS
# SENSOR_MODEL                                                          MCOMS_FLBBCD
# SENSOR_SERIAL_NO                                                               419
# SENSOR_CALIB_DATE                                                             None
# COMMENTS
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'KHI': 1.097, 'BETASW700': 'calculated at 124...
#
#                                                          SPECTROPHOTOMETER_NITRATE  \
# SENSOR_MAKER                                                             SATLANTIC
# SENSOR_MODEL                                                               SUNA_V2
# SENSOR_SERIAL_NO                                                              2068
# SENSOR_CALIB_DATE                                                             None
# COMMENTS                                                                      None
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'NO3': [-0.00022323, 0.00585584, 0.00472827, ...
#
#                                                                      TRANSISTOR_PH
# SENSOR_MAKER                                                                   SBE
# SENSOR_MODEL                                                                SEAFET
# SENSOR_SERIAL_NO                                                         720-12256
# SENSOR_CALIB_DATE                                                       2023-03-14
# COMMENTS                           REF SN: 12246; added calibration date; added K0
# PREDEPLOYMENT_CALIB_EQUATION                                         {'eq1': None}
# PREDEPLOYMENT_CALIB_COEFFICIENT  {'F0': -1.332894357998, 'F1': 8.811211536684e-...

# %%
cal = []
for i, metas in enumerate(meta):
    cal.append(metas["OPTODE_DOXY"].PREDEPLOYMENT_CALIB_COEFFICIENT)
cal
# Out:
# [{'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.429848,
#   'B0': -0.256176,
#   'B1': 1.66524,
#   'C0': 0.105454,
#   'C1': 0.00448639,
#   'C2': 6.29384e-05,
#   'TA0': 0.0007423849,
#   'TA1': 0.000240347,
#   'TA2': 1.73386e-06,
#   'TA3': 6.398761e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.43458,
#   'B0': -0.247898,
#   'B1': 1.66598,
#   'C0': 0.100015,
#   'C1': 0.00427755,
#   'C2': 5.81681e-05,
#   'TA0': 0.0007155221,
#   'TA1': 0.000247788,
#   'TA2': 1.02282e-06,
#   'TA3': 8.70394e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.394721,
#   'B0': -0.253923,
#   'B1': 1.62961,
#   'C0': 0.109616,
#   'C1': 0.00467122,
#   'C2': 6.58318e-05,
#   'TA0': 0.000689967,
#   'TA1': 0.000255527,
#   'TA2': 2.57012e-07,
#   'TA3': 1.12234e-07},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.399442,
#   'B0': -0.249977,
#   'B1': 1.63137,
#   'C0': 0.108168,
#   'C1': 0.00461289,
#   'C2': 6.401091e-05,
#   'TA0': 0.000720534,
#   'TA1': 0.000246691,
#   'TA2': 1.1074e-06,
#   'TA3': 8.418821e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.369775,
#   'B0': -0.253984,
#   'B1': 1.60518,
#   'C0': 0.113243,
#   'C1': 0.00483077,
#   'C2': 6.745811e-05,
#   'TA0': 0.000713211,
#   'TA1': 0.000248136,
#   'TA2': 9.8078e-07,
#   'TA3': 8.77536e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.477796,
#   'B0': -0.242629,
#   'B1': 1.70149,
#   'C0': 0.0970456,
#   'C1': 0.00412529,
#   'C2': 5.6426e-05,
#   'TA0': 0.0007188769,
#   'TA1': 0.000247431,
#   'TA2': 1.06451e-06,
#   'TA3': 8.510012e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.388274,
#   'B0': -0.253531,
#   'B1': 1.62323,
#   'C0': 0.110331,
#   'C1': 0.00470824,
#   'C2': 6.580911e-05,
#   'TA0': 0.000704315,
#   'TA1': 0.000251241,
#   'TA2': 6.81124e-07,
#   'TA3': 9.829471e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.476599,
#   'B0': -0.242254,
#   'B1': 1.70089,
#   'C0': 0.0965734,
#   'C1': 0.004108,
#   'C2': 5.614501e-05,
#   'TA0': 0.000717288,
#   'TA1': 0.000246782,
#   'TA2': 1.09344e-06,
#   'TA3': 8.58389e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.375261,
#   'B0': -0.250634,
#   'B1': 1.60835,
#   'C0': 0.109898,
#   'C1': 0.0046774,
#   'C2': 6.59295e-05,
#   'TA0': 0.0007146,
#   'TA1': 0.000247939,
#   'TA2': 1.00909e-06,
#   'TA3': 8.800969e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.391677,
#   'B0': -0.249151,
#   'B1': 1.62374,
#   'C0': 0.107684,
#   'C1': 0.00458129,
#   'C2': 6.48213e-05,
#   'TA0': 0.000708242,
#   'TA1': 0.000249611,
#   'TA2': 8.54823e-07,
#   'TA3': 9.232349e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.410242,
#   'B0': -0.250022,
#   'B1': 1.64243,
#   'C0': 0.106985,
#   'C1': 0.00454508,
#   'C2': 6.41817e-05,
#   'TA0': 0.000757665,
#   'TA1': 0.000235291,
#   'TA2': 2.21794e-06,
#   'TA3': 4.844561e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.395891,
#   'B0': -0.251047,
#   'B1': 1.62865,
#   'C0': 0.109157,
#   'C1': 0.00463597,
#   'C2': 6.55165e-05,
#   'TA0': 0.000722951,
#   'TA1': 0.000246071,
#   'TA2': 1.17676e-06,
#   'TA3': 8.240281e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.429988,
#   'B0': -0.246107,
#   'B1': 1.66024,
#   'C0': 0.100755,
#   'C1': 0.00429564,
#   'C2': 5.93054e-05,
#   'TA0': 0.0007145989,
#   'TA1': 0.000247956,
#   'TA2': 9.826541e-07,
#   'TA3': 8.80862e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.476821,
#   'B0': -0.242725,
#   'B1': 1.70038,
#   'C0': 0.09679991,
#   'C1': 0.00416945,
#   'C2': 5.44306e-05,
#   'TA0': 0.000730316,
#   'TA1': 0.000243482,
#   'TA2': 1.4225e-06,
#   'TA3': 7.41014e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.405394,
#   'B0': -0.249913,
#   'B1': 1.63738,
#   'C0': 0.107353,
#   'C1': 0.00457467,
#   'C2': 6.38711e-05,
#   'TA0': 0.0006684829,
#   'TA1': 0.000261085,
#   'TA2': -2.86088e-07,
#   'TA3': 1.29475e-07},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.393289,
#   'B0': -0.254081,
#   'B1': 1.62804,
#   'C0': 0.109698,
#   'C1': 0.00467089,
#   'C2': 6.50991e-05,
#   'TA0': 0.000707076,
#   'TA1': 0.00025059,
#   'TA2': 7.291609e-07,
#   'TA3': 9.709439e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.4145,
#   'B0': -0.250033,
#   'B1': 1.64604,
#   'C0': 0.106193,
#   'C1': 0.00451145,
#   'C2': 6.35604e-05,
#   'TA0': 0.000737533,
#   'TA1': 0.000241503,
#   'TA2': 1.62804e-06,
#   'TA3': 6.74881e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.354942,
#   'B0': -0.24739,
#   'B1': 1.586,
#   'C0': 0.112153,
#   'C1': 0.00478172,
#   'C2': 6.76763e-05,
#   'TA0': 0.000702993,
#   'TA1': 0.000251908,
#   'TA2': 6.14424e-07,
#   'TA3': 1.0082e-07},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.355163,
#   'B0': -0.246014,
#   'B1': 1.58518,
#   'C0': 0.112287,
#   'C1': 0.00477573,
#   'C2': 6.75717e-05,
#   'TA0': 0.000702993,
#   'TA1': 0.00025092,
#   'TA2': 7.14816e-07,
#   'TA3': 9.65484e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.395479,
#   'B0': -0.245617,
#   'B1': 1.62364,
#   'C0': 0.107114,
#   'C1': 0.00455646,
#   'C2': 6.40388e-05,
#   'TA0': 0.0007348609,
#   'TA1': 0.000242336,
#   'TA2': 1.53805e-06,
#   'TA3': 7.016101e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.3898,
#   'B0': -0.23773,
#   'B1': 1.6136,
#   'C0': 0.10187,
#   'C1': 0.0043836,
#   'C2': 6.1362e-05,
#   'TA0': 0.0007270966,
#   'TA1': 0.0002437583,
#   'TA2': 1.397296e-06,
#   'TA3': 7.592994e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.431171,
#   'B0': -0.240276,
#   'B1': 1.65567,
#   'C0': 0.0991185,
#   'C1': 0.00424414,
#   'C2': 5.718431e-05,
#   'TA0': 0.000778152,
#   'TA1': 0.00022889,
#   'TA2': 2.83707e-06,
#   'TA3': 2.97392e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.377014,
#   'B0': -0.244194,
#   'B1': 1.60561,
#   'C0': 0.108206,
#   'C1': 0.00462515,
#   'C2': 6.33251e-05,
#   'TA0': 0.000735701,
#   'TA1': 0.000241871,
#   'TA2': 1.56996e-06,
#   'TA3': 7.04439e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.392183,
#   'B0': -0.244231,
#   'B1': 1.62366,
#   'C0': 0.10164,
#   'C1': 0.00439328,
#   'C2': 6.05628e-05,
#   'TA0': 0.000729928,
#   'TA1': 0.000243975,
#   'TA2': 1.36945e-06,
#   'TA3': 7.69779e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.380476,
#   'B0': -0.246979,
#   'B1': 1.61022,
#   'C0': 0.105893,
#   'C1': 0.00451387,
#   'C2': 6.404009e-05,
#   'TA0': 0.0007181349,
#   'TA1': 0.000247138,
#   'TA2': 1.06877e-06,
#   'TA3': 8.729752e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.424021,
#   'B0': -0.248514,
#   'B1': 1.6557,
#   'C0': 0.10191,
#   'C1': 0.00433745,
#   'C2': 6.00669e-05,
#   'TA0': 0.000686906,
#   'TA1': 0.000256362,
#   'TA2': 1.78602e-07,
#   'TA3': 1.15265e-07},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.400592,
#   'B0': -0.246781,
#   'B1': 1.63005,
#   'C0': 0.105513,
#   'C1': 0.00447846,
#   'C2': 6.332319e-05,
#   'TA0': 0.000756225,
#   'TA1': 0.000236276,
#   'TA2': 2.13635e-06,
#   'TA3': 5.204651e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.38832,
#   'B0': -0.24961,
#   'B1': 1.6222,
#   'C0': 0.10624,
#   'C1': 0.004534,
#   'C2': 6.2409e-05,
#   'TA0': 0.0007189533,
#   'TA1': 0.0002462013,
#   'TA2': 1.169661e-06,
#   'TA3': 8.384281e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.429112,
#   'B0': -0.25366,
#   'B1': 1.66475,
#   'C0': 0.102075,
#   'C1': 0.0043737,
#   'C2': 5.92373e-05,
#   'TA0': 0.000724134,
#   'TA1': 0.000245315,
#   'TA2': 1.23633e-06,
#   'TA3': 8.062619e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.380652,
#   'B0': -0.25108,
#   'B1': 1.61421,
#   'C0': 0.107363,
#   'C1': 0.00458098,
#   'C2': 6.43679e-05,
#   'TA0': 0.0007698541,
#   'TA1': 0.000232189,
#   'TA2': 2.50497e-06,
#   'TA3': 4.03765e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.386213,
#   'B0': -0.245108,
#   'B1': 1.61632,
#   'C0': 0.105869,
#   'C1': 0.00451672,
#   'C2': 6.28947e-05,
#   'TA0': 0.000711752,
#   'TA1': 0.000248689,
#   'TA2': 9.20609e-07,
#   'TA3': 9.158981e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.413991,
#   'B0': -0.240715,
#   'B1': 1.642,
#   'C0': 0.098204,
#   'C1': 0.00423501,
#   'C2': 5.84512e-05,
#   'TA0': 0.000700367,
#   'TA1': 0.000252175,
#   'TA2': 5.673719e-07,
#   'TA3': 1.02737e-07},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.375606,
#   'B0': -0.249402,
#   'B1': 1.60687,
#   'C0': 0.108216,
#   'C1': 0.00461874,
#   'C2': 6.43687e-05,
#   'TA0': 0.000730902,
#   'TA1': 0.000243069,
#   'TA2': 1.45102e-06,
#   'TA3': 7.41432e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.352206,
#   'B0': -0.246272,
#   'B1': 1.58415,
#   'C0': 0.111328,
#   'C1': 0.00475538,
#   'C2': 6.607711e-05,
#   'TA0': 0.0007420909,
#   'TA1': 0.000239642,
#   'TA2': 1.79539e-06,
#   'TA3': 6.41068e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.406372,
#   'B0': -0.246021,
#   'B1': 1.63581,
#   'C0': 0.101984,
#   'C1': 0.004351911,
#   'C2': 6.13763e-05,
#   'TA0': 0.0007395849,
#   'TA1': 0.000240472,
#   'TA2': 1.72014e-06,
#   'TA3': 6.48262e-08},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.408686,
#   'B0': -0.245043,
#   'B1': 1.6372,
#   'C0': 0.102127,
#   'C1': 0.00436516,
#   'C2': 6.09198e-05,
#   'TA0': 0.000701848,
#   'TA1': 0.000251812,
#   'TA2': 6.071691e-07,
#   'TA3': 1.0115e-07},
#  {'E': 0.011,
#   'A0': 1.0513,
#   'A1': -0.0015,
#   'A2': 0.435179,
#   'B0': -0.251613,
#   'B1': 1.66978,
#   'C0': 0.10058,
#   'C1': 0.00432115,
#   'C2': 5.80785e-05,
#   'TA0': 0.000743871,
#   'TA1': 0.000239445,
#   'TA2': 1.82911e-06,
#   'TA3': 6.113319e-08}]

# %%
variables = ["E", "A0", "A1", "A2", "B0", "B1", "C0", "C1", "C2", "TA0", "TA1", "TA2", "TA3"]
counter = 0

for variable in variables:
    coefficients = []
    serials = []
    counter2 = 0
    for num in cal: 
        if variable in num:
            coefficients.append(num[variable])
            serials.append(sn[counter2])
        counter2+=1
    
    coefficient_array = np.array(coefficients)
    coeff_array = np.delete(coefficient_array, np.where(coefficient_array == None))
    #print(coeff_array)
    print(variable)
    mean = coeff_array.mean()
    std = coeff_array.std()
    print("The mean is:", coeff_array.mean())
    print("The std is:", coeff_array.std())

    plt.figure(counter)
    plt.xlabel("FLOAT SERIAL NO")
    plt.ylabel("VALUE")
    plt.title(variable)
    plt.scatter(serials,coefficients)
    plt.axhline(y = mean, color='green')
    #plt.axhline(y = std, color= 'red')
    plt.xticks(rotation= 75)
    counter+=1
# Out:
# E
# The mean is: 0.011000000000000001
# The std is: 1.734723475976807e-18
# A0
# The mean is: 1.0512999999999997
# The std is: 2.220446049250313e-16
# A1
# The mean is: -0.0015000000000000002
# The std is: 2.168404344971009e-19
# A2
# The mean is: 0.40381827027027023
# The std is: 0.030798408472963248
# B0
# The mean is: -0.24784689189189194
# The std is: 0.004267687802253329
# B1
# The mean is: 1.6346178378378378
# The std is: 0.029477100698598647
# C0
# The mean is: 0.10526106513513513
# The std is: 0.004610282063250912
# C1
# The mean is: 0.004492562189189189
# The std is: 0.00018876336207750174
# C2
# The mean is: 6.245499297297297e-05
# The std is: 3.398582641667334e-06
# TA0
# The mean is: 0.0007227003054054053
# The std is: 2.2146542313917387e-05
# TA1
# The mean is: 0.0002456733675675676
# The std is: 6.483364992124869e-06
# TA2
# The mean is: 1.2135779729729728e-06
# The std is: 6.279499224145233e-07
# TA3
# The mean is: 8.139525189189188e-08
# The std is: 2.016289703497569e-08
